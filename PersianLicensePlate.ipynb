# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.9/645.9 kB 8.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 328MB/s]

# %%
model.train(data="/content/drive/MyDrive/Dataset/PersianLicensePlate/data.yaml", epochs=50)
# Out:
# Ultralytics YOLOv8.0.219 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
new_model = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
result = new_model("/content/drive/MyDrive/Assets/cars.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Assets/cars.jpg: 640x640 4 License-Plates, 95.7ms
# Speed: 1.9ms preprocess, 95.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread("/content/runs/detect/predict/cars.jpg")
image = cv2.cvtColor(image , cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()
